# %% [markdown]
# # Football Events and Game Information

# %% [markdown]
# ### Imports and initializations

# %%
# imports used in the project

import zipfile
import numpy as np 
import scipy as sp 
import matplotlib as mpl
import matplotlib.cm as cm 
import matplotlib.pyplot as plt
import pandas as pd 
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
sns.set(style="whitegrid")
import warnings
warnings.filterwarnings('ignore')
from collections import Counter

# %%
# plots descriptions
#Can be googled to find optimum style.

plt.style.use(['dark_background', 'bmh'])
plt.rc('axes', facecolor='k')
plt.rc('figure', facecolor='k')
plt.rc('figure', figsize=(5,5))

# %% [markdown]
# # Data Processing and Engineering

# %% [markdown]
# ### Import the data from CSV

# %%
# Read the data from CSV files into pandas data frame

df_events = pd.read_csv("events.csv")
df_game_info = pd.read_csv("ginf.csv")

# %%
# Encode the data into respective data frames

encoding = pd.read_table('Data/dictionary.txt', delim_whitespace=False, names=('num','events'))
event_type=encoding[1:13]
event_type_2=encoding[14:18]
side=encoding[19:21]
shot_place=encoding[22:35]
shot_outcome=encoding[36:40]
location=encoding[41:60]
bodypart=encoding[61:64]
assist_method=encoding[65:70]
situition=encoding[71:75]

# %%
# Manually convert the dictionary.txt to python dictionaries

event_types = {1:'Attempt', 2:'Corner', 3:'Foul', 4:'Yellow card', 5:'Second yellow card', 6:'Red card', 7:'Substitution', 8:'Free kick won', 9:'Offside', 10:'Hand ball', 11:'Penalty conceded'}
event_types2 = {12:'Key Pass', 13:'Failed through ball', 14:'Sending off', 15:'Own goal'}
sides = {1:'Home', 2:'Away'}
shot_places = {1:'Bit too high', 2:'Blocked', 3:'Bottom left corner', 4:'Bottom right corner', 5:'Centre of the goal', 6:'High and wide', 7:'Hits the bar', 8:'Misses to the left', 9:'Misses to the right', 10:'Too high', 11:'Top centre of the goal', 12:'Top left corner', 13:'Top right corner'}
shot_outcomes = {1:'On target', 2:'Off target', 3:'Blocked', 4:'Hit the bar'}
locations = {1:'Attacking half', 2:'Defensive half', 3:'Centre of the box', 4:'Left wing', 5:'Right wing', 6:'Difficult angle and long range', 7:'Difficult angle on the left', 8:'Difficult angle on the right', 9:'Left side of the box', 10:'Left side of the six yard box', 11:'Right side of the box', 12:'Right side of the six yard box', 13:'Very close range', 14:'Penalty spot', 15:'Outside the box', 16:'Long range', 17:'More than 35 yards', 18:'More than 40 yards', 19:'Not recorded'}
bodyparts = {1:'right foot', 2:'left foot', 3:'head'}
assist_methods = {1:'Pass', 2:'Cross', 3:'Headed pass', 4:'Through ball'}
situations = {1:'Open play', 2:'Set piece', 3:'Corner', 4:'Free kick'}

# %%
## Map the leagues' names to their popular names for easier understanding
leagues = {'E0': 'Premier League', 'SP1': 'La Liga',
          'I1': 'Serie A', 'F1': 'League One', 'D1': 'Bundesliga'}

## Map them to events
df_game_info.league = df_game_info.league.map(leagues)

# %%
# Map the dictionaries onto the events dataframe

df_events['event_type'] =   df_events['event_type'].map(event_types)
df_events['event_type2'] =  df_events['event_type2'].map(event_types2)
df_events['side'] =         df_events['side'].map(sides)
df_events['shot_place'] =   df_events['shot_place'].map(shot_places)
df_events['shot_outcome']=  df_events['shot_outcome'].map(shot_outcomes)
df_events['location'] =     df_events['location'].map(locations)
df_events['bodypart'] =     df_events['bodypart'].map(bodyparts)
df_events['assist_method']= df_events['assist_method'].map(assist_methods)
df_events['situation'] =    df_events['situation'].map(situations)

# %% [markdown]
# ## Data Engineering

# %%
# Merge other dataset to have country, league, date and season
df_events = df_events.merge(df_game_info ,how = 'left')

# %%
df_game_info.season = df_game_info.season.astype('category')
df_game_info.league = df_game_info.league.astype('category')
df_game_info.country = df_game_info.country.astype('category')

# %%
df_game_info.league.unique()
# Out:
# [Bundesliga, League One, Premier League, La Liga, Serie A]
# Categories (5, object): [Bundesliga, League One, Premier League, La Liga, Serie A]

# %%
assist_method
# Out:
#    num        events
# 65   0          None
# 66   1          Pass
# 67   2         Cross
# 68   3   Headed pass
# 69   4  Through ball

# %% [markdown]
# ### Handle Missing Values

# %%
# Function to calculate missing values by column# Funct 
def missing_values_table(df):
        # Total missing values
        mis_val = df.isnull().sum()
        
        # Percentage of missing values
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        
        # Make a table with the results
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        
        # Rename the columns
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        
        # Sort the table by percentage of missing descending
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        
        # Print some summary information
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        
        # Return the dataframe with missing information
        return mis_val_table_ren_columns

# %%
missing_values_table(df_events)
# Out:
# Your selected dataframe has 39 columns.
# There are 15 columns that have missing values.
#                Missing Values  % of Total Values
# player_in              889294               94.5
# player_out             889271               94.5
# odd_over               842329               89.5
# odd_under              842329               89.5
# odd_bts                842329               89.5
# odd_bts_n              842329               89.5
# assist_method          773104               82.2
# event_type2            726716               77.2
# shot_place             713550               75.8
# shot_outcome           712511               75.7
# situation              711872               75.6
# bodypart               711824               75.6
# player2                649699               69.0
# location               473942               50.4
# player                  61000                6.5

# %%
# Fill the required features with new class 'unknown'
df_events.shot_place.fillna('UNK', inplace= True)
df_events.player.fillna('UNK', inplace= True)
df_events.shot_outcome.fillna('UNK', inplace= True)
df_events.bodypart.fillna('UNK', inplace= True)
df_events.location.fillna('UNK', inplace= True)
df_events.assist_method.fillna('UNK', inplace= True);

# %%
df_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 941009 entries, 0 to 941008
# Data columns (total 39 columns):
# id_odsp          941009 non-null object
# id_event         941009 non-null object
# sort_order       941009 non-null int64
# time             941009 non-null int64
# text             941009 non-null object
# event_type       941009 non-null object
# event_type2      214293 non-null object
# side             941009 non-null object
# event_team       941009 non-null object
# opponent         941009 non-null object
# player           941009 non-null object
# player2          291310 non-null object
# player_in        51715 non-null object
# player_out       51738 non-null object
# shot_place       941009 non-null object
# shot_outcome     941009 non-null object
# is_goal          941009 non-null int64
# location         941009 non-null object
# bodypart         941009 non-null object
# assist_method    941009 non-null object
# situation        229137 non-null object
# fast_break       941009 non-null int64
# link_odsp        941009 non-null object
# adv_stats        941009 non-null bool
# date             941009 non-null object
# league           941009 non-null object
# season           941009 non-null int64
# country          941009 non-null object
# ht               941009 non-null object
# at               941009 non-null object
# fthg             941009 non-null int64
# ftag             941009 non-null int64
# odd_h            941009 non-null float64
# odd_d            941009 non-null float64
# odd_a            941009 non-null float64
# odd_over         98680 non-null float64
# odd_under        98680 non-null float64
# odd_bts          98680 non-null float64
# odd_bts_n        98680 non-null float64
# dtypes: bool(1), float64(7), int64(7), object(24)
# memory usage: 280.9+ MB

# %%
# Notice that a lot of the floats and ints are in fact categoricals
# We can fix this with Pandas' astype function
categoricals = ['id_odsp', 'event_type', 'event_team', 'opponent', 'shot_place', 'shot_outcome', 'location', 'bodypart', 'assist_method', 'situation', 'side']
d = dict.fromkeys(categoricals,'category')
df_events = df_events.astype(d)
df_events['is_goal'] = df_events['is_goal'].astype('bool') # this is a bool, we can fix that too while we're at it

# %%
df_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 941009 entries, 0 to 941008
# Data columns (total 39 columns):
# id_odsp          941009 non-null category
# id_event         941009 non-null object
# sort_order       941009 non-null int64
# time             941009 non-null int64
# text             941009 non-null object
# event_type       941009 non-null category
# event_type2      214293 non-null object
# side             941009 non-null category
# event_team       941009 non-null category
# opponent         941009 non-null category
# player           941009 non-null object
# player2          291310 non-null object
# player_in        51715 non-null object
# player_out       51738 non-null object
# shot_place       941009 non-null category
# shot_outcome     941009 non-null category
# is_goal          941009 non-null bool
# location         941009 non-null category
# bodypart         941009 non-null category
# assist_method    941009 non-null category
# situation        229137 non-null category
# fast_break       941009 non-null int64
# link_odsp        941009 non-null object
# adv_stats        941009 non-null bool
# date             941009 non-null object
# league           941009 non-null object
# season           941009 non-null int64
# country          941009 non-null object
# ht               941009 non-null object
# at               941009 non-null object
# fthg             941009 non-null int64
# ftag             941009 non-null int64
# odd_h            941009 non-null float64
# odd_d            941009 non-null float64
# odd_a            941009 non-null float64
# odd_over         98680 non-null float64
# odd_under        98680 non-null float64
# odd_bts          98680 non-null float64
# odd_bts_n        98680 non-null float64
# dtypes: bool(2), category(11), float64(7), int64(6), object(13)
# memory usage: 208.6+ MB

# %% [markdown]
# # Data Analysis and Visualisations

# %% [markdown]
# ### Create the cards dataframes

# %%
df_unique_events = df_events.drop_duplicates()

# %%
# Get the yellow cards data

first_yellow_cards = df_unique_events [df_unique_events ['event_type'] == ('Yellow card')] # select first yellow cards
second_yellow_cards= df_unique_events [df_unique_events ['event_type'] == ('Second yellow card')] # select second yellow cards
red_cards = df_unique_events [df_unique_events['event_type'] == ('Red card')] # select red cards
yellow_cards= df_unique_events [df_unique_events ['event_type'] == ('Yellow card' or 'Second yellow card')]

card_frames = [red_cards, yellow_cards]
all_cards = pd.concat(card_frames)

# %% [markdown]
# ### Graph to show when red cards are most likely to be served

# %%
# Get the yellow cards against time of playing the game
fig = plt.figure(figsize=(14,8))
plt.hist(red_cards.time, 100, color="red")
plt.xlabel("Minute  of the Game")
plt.ylabel("Red Cards")
plt.title("When Red Cards Occur")
# Out:
# Text(0.5, 1.0, 'When Red Cards Occur')

# %% [markdown]
# ### Graph to show when the yellow cards are most likely to be served

# %%
# plot the second yellow cards against time of playing the game

fig2 = plt.figure(figsize=(14,8))
plt.hist(first_yellow_cards.time, 100, color="yellow")
plt.xlabel("Minute of the Game")
plt.ylabel("First Yellow Cards")
plt.title("When First Yellow Cards Occur")
# Out:
# Text(0.5, 1.0, 'When First Yellow Cards Occur')

# %%
# Out:
#           id_odsp     id_event  sort_order  time                                               text   event_type event_type2  side             event_team               opponent               player player2 player_in player_out shot_place shot_outcome  is_goal location bodypart assist_method situation  fast_break                                          link_odsp  adv_stats        date          league  season  country                   ht                     at  fthg  ftag  odd_h  odd_d  odd_a  \
# 44      UFot0hit/   UFot0hit45          45    45  Michael Mancienne (Hamburg) is shown the yello...  Yellow card         NaN  Away             Hamburg SV      Borussia Dortmund    michael mancienne     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/germany/bundesliga-2011-2012/dortmund-...       True  2011-08-05      Bundesliga    2012  germany    Borussia Dortmund             Hamburg SV     3     1   1.56   4.41   7.42
# 76      UFot0hit/   UFot0hit77          77    68  Gojko Kacar (Hamburg) is shown the yellow card...  Yellow card         NaN  Away             Hamburg SV      Borussia Dortmund          gojko kacar     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/germany/bundesliga-2011-2012/dortmund-...       True  2011-08-05      Bundesliga    2012  germany    Borussia Dortmund             Hamburg SV     3     1   1.56   4.41   7.42
# 79      UFot0hit/   UFot0hit80          80    69  Tomas Rincon (Hamburg) is shown the yellow car...  Yellow card         NaN  Away             Hamburg SV      Borussia Dortmund         tomas rincon     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/germany/bundesliga-2011-2012/dortmund-...       True  2011-08-05      Bundesliga    2012  germany    Borussia Dortmund             Hamburg SV     3     1   1.56   4.41   7.42
# 101     UFot0hit/  UFot0hit102         102    85  Robert Lewandowski (Borussia Dortmund) is show...  Yellow card         NaN  Home      Borussia Dortmund             Hamburg SV   robert lewandowski     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/germany/bundesliga-2011-2012/dortmund-...       True  2011-08-05      Bundesliga    2012  germany    Borussia Dortmund             Hamburg SV     3     1   1.56   4.41   7.42
# 118     Aw5DflLH/    Aw5DflLH9           9     5  Marcel de Jong (FC Augsburg) is shown the yell...  Yellow card         NaN  Home            FC Augsburg            SC Freiburg       marcel de jong     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/germany/bundesliga-2011-2012/augsburg-...       True  2011-08-06      Bundesliga    2012  germany          FC Augsburg            SC Freiburg     2     2   2.36   3.60   3.40
# 125     Aw5DflLH/   Aw5DflLH16          16    10  Tobias Werner (FC Augsburg) is shown the yello...  Yellow card         NaN  Home            FC Augsburg            SC Freiburg        tobias werner     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/germany/bundesliga-2011-2012/augsburg-...       True  2011-08-06      Bundesliga    2012  germany          FC Augsburg            SC Freiburg     2     2   2.36   3.60   3.40
# 153     Aw5DflLH/   Aw5DflLH44          44    29  Oliver Barth (SC Freiburg) is shown the yellow...  Yellow card         NaN  Away            SC Freiburg            FC Augsburg         oliver barth     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/germany/bundesliga-2011-2012/augsburg-...       True  2011-08-06      Bundesliga    2012  germany          FC Augsburg            SC Freiburg     2     2   2.36   3.60   3.40
# 192     Aw5DflLH/   Aw5DflLH83          83    61  Daniel Caligiuri (SC Freiburg) is shown the ye...  Yellow card         NaN  Away            SC Freiburg            FC Augsburg     daniel caligiuri     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/germany/bundesliga-2011-2012/augsburg-...       True  2011-08-06      Bundesliga    2012  germany          FC Augsburg            SC Freiburg     2     2   2.36   3.60   3.40
# 218     Aw5DflLH/  Aw5DflLH109         109    85  Mensur Mujdza (SC Freiburg) is shown the yello...  Yellow card         NaN  Away            SC Freiburg            FC Augsburg        mensur mujdza     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/germany/bundesliga-2011-2012/augsburg-...       True  2011-08-06      Bundesliga    2012  germany          FC Augsburg            SC Freiburg     2     2   2.36   3.60   3.40
# 231     Aw5DflLH/  Aw5DflLH122         122    90  Johannes Flum (SC Freiburg) is shown the yello...  Yellow card         NaN  Away            SC Freiburg            FC Augsburg        johannes flum     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/germany/bundesliga-2011-2012/augsburg-...       True  2011-08-06      Bundesliga    2012  germany          FC Augsburg            SC Freiburg     2     2   2.36   3.60   3.40
# 258     bkjpaC6n/   bkjpaC6n27          27    17  Richard Sukuta-Pasu (Kaiserslautern) is shown ...  Yellow card         NaN  Away         Kaiserslautern          Werder Bremen   richard sukutapasu     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/germany/bundesliga-2011-2012/werder-br...       True  2011-08-06      Bundesliga    2012  germany        Werder Bremen         Kaiserslautern     2     0   1.83   4.20   4.80
# 330     bkjpaC6n/   bkjpaC6n99          99    71  Wesley (SV Werder Bremen) is shown the yellow ...  Yellow card         NaN  Home          Werder Bremen         Kaiserslautern               wesley     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/germany/bundesliga-2011-2012/werder-br...       True  2011-08-06      Bundesliga    2012  germany        Werder Bremen         Kaiserslautern     2     0   1.83   4.20   4.80
# 336     bkjpaC6n/  bkjpaC6n105         105    73  Florian Dick (Kaiserslautern) is shown the yel...  Yellow card         NaN  Away         Kaiserslautern          Werder Bremen         florian dick     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/germany/bundesliga-2011-2012/werder-br...       True  2011-08-06      Bundesliga    2012  germany        Werder Bremen         Kaiserslautern     2     0   1.83   4.20   4.80
# 394     CzPV312a/   CzPV312a26          26    25  Yann Jouffre (Lorient) is shown the yellow car...  Yellow card         NaN  Away                Lorient    Paris Saint-Germain         yann jouffre     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/france/ligue-1-2011-2012/paris-sg-lori...       True  2011-08-06      League One    2012   france  Paris Saint-Germain                Lorient     0     1   1.55   4.50   9.40
# 408     CzPV312a/   CzPV312a40          40    35  ClA©ment Chantome (Paris Saint Germain) is sho...  Yellow card         NaN  Home    Paris Saint-Germain                Lorient     clement chantome     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/france/ligue-1-2011-2012/paris-sg-lori...       True  2011-08-06      League One    2012   france  Paris Saint-Germain                Lorient     0     1   1.55   4.50   9.40
# 474     CzPV312a/  CzPV312a106         106    88  Arnold Mvuemba (Lorient) is shown the yellow c...  Yellow card         NaN  Away                Lorient    Paris Saint-Germain       arnold mvuemba     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/france/ligue-1-2011-2012/paris-sg-lori...       True  2011-08-06      League One    2012   france  Paris Saint-Germain                Lorient     0     1   1.55   4.50   9.40
# 477     CzPV312a/  CzPV312a109         109    89  Lynel Kitambala (Lorient) is shown the yellow ...  Yellow card         NaN  Away                Lorient    Paris Saint-Germain      lynel kitambala     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/france/ligue-1-2011-2012/paris-sg-lori...       True  2011-08-06      League One    2012   france  Paris Saint-Germain                Lorient     0     1   1.55   4.50   9.40
# 496     GUOdmtII/   GUOdmtII14          14    17  Carlos SA¡nchez (Valenciennes) is shown the ye...  Yellow card         NaN  Away           Valenciennes                   Caen       carlos sanchez     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/france/ligue-1-2011-2012/caen-valencie...       True  2011-08-06      League One    2012   france                 Caen           Valenciennes     1     0   2.50   3.40   3.45
# 552     GUOdmtII/   GUOdmtII70          70    75  Damien Marcq (Caen) is shown the yellow card f...  Yellow card         NaN  Home                   Caen           Valenciennes         damien marcq     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/france/ligue-1-2011-2012/caen-valencie...       True  2011-08-06      League One    2012   france                 Caen           Valenciennes     1     0   2.50   3.40   3.45
# 572     GUOdmtII/   GUOdmtII90          90    90  Pierre-Alain Frau (Caen) is shown the yellow c...  Yellow card         NaN  Home                   Caen           Valenciennes     pierrealain frau     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/france/ligue-1-2011-2012/caen-valencie...       True  2011-08-06      League One    2012   france                 Caen           Valenciennes     1     0   2.50   3.40   3.45
# 599     lOpzwMkp/   lOpzwMkp27          27    15  Markus Feulner (FC Nurnberg) is shown the yell...  Yellow card         NaN  Away               Nurnberg          Hertha Berlin       markus feulner     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/germany/bundesliga-2011-2012/hertha-be...       True  2011-08-06      Bundesliga    2012  germany        Hertha Berlin               Nurnberg     0     1   2.06   3.75   3.95
# 639     lOpzwMkp/   lOpzwMkp67          67    45  Peter Niemeyer (Hertha Berlin) is shown the ye...  Yellow card         NaN  Home          Hertha Berlin               Nurnberg       peter niemeyer     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/germany/bundesliga-2011-2012/hertha-be...       True  2011-08-06      Bundesliga    2012  germany        Hertha Berlin               Nurnberg     0     1   2.06   3.75   3.95
# 658     lOpzwMkp/   lOpzwMkp86          86    52  Levan Kobiashvili (Hertha Berlin) is shown the...  Yellow card         NaN  Home          Hertha Berlin               Nurnberg    levan kobiashvili     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/germany/bundesliga-2011-2012/hertha-be...       True  2011-08-06      Bundesliga    2012  germany        Hertha Berlin               Nurnberg     0     1   2.06   3.75   3.95
# 677     lOpzwMkp/  lOpzwMkp105         105    67  Almog Cohen (FC Nurnberg) is shown the yellow ...  Yellow card         NaN  Away               Nurnberg          Hertha Berlin          almog cohen     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/germany/bundesliga-2011-2012/hertha-be...       True  2011-08-06      Bundesliga    2012  germany        Hertha Berlin               Nurnberg     0     1   2.06   3.75   3.95
# 701     lOpzwMkp/  lOpzwMkp129         129    89  Alexander Esswein (FC Nurnberg) is shown the y...  Yellow card         NaN  Away               Nurnberg          Hertha Berlin    alexander esswein     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/germany/bundesliga-2011-2012/hertha-be...       True  2011-08-06      Bundesliga    2012  germany        Hertha Berlin               Nurnberg     0     1   2.06   3.75   3.95
# 743     M7PhlM2C/   M7PhlM2C36          36    29  Nolan Roux (Brest) is shown the yellow card fo...  Yellow card         NaN  Home                  Brest  Evian Thonon Gaillard           nolan roux     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/france/ligue-1-2011-2012/brest-evian-t...       True  2011-08-06      League One    2012   france                Brest  Evian Thonon Gaillard     2     2   2.29   3.25   3.85
# 752     M7PhlM2C/   M7PhlM2C45          45    35  Aldo Angoula (Evian Thonon Gaillard) is shown ...  Yellow card         NaN  Away  Evian Thonon Gaillard                  Brest         aldo angoula     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/france/ligue-1-2011-2012/brest-evian-t...       True  2011-08-06      League One    2012   france                Brest  Evian Thonon Gaillard     2     2   2.29   3.25   3.85
# 760     M7PhlM2C/   M7PhlM2C53          53    38  Sidney Govou (Evian Thonon Gaillard) is shown ...  Yellow card         NaN  Away  Evian Thonon Gaillard                  Brest         sidney govou     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/france/ligue-1-2011-2012/brest-evian-t...       True  2011-08-06      League One    2012   france                Brest  Evian Thonon Gaillard     2     2   2.29   3.25   3.85
# 813     M7PhlM2C/  M7PhlM2C106         106    86  Jhon Culma Jairo (Brest) is shown the yellow c...  Yellow card         NaN  Home                  Brest  Evian Thonon Gaillard     jhon culma jairo     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/france/ligue-1-2011-2012/brest-evian-t...       True  2011-08-06      League One    2012   france                Brest  Evian Thonon Gaillard     2     2   2.29   3.25   3.85
# 864     QuWqjrYa/   QuWqjrYa42          42    33  Johan Cavalli (Ajaccio) is shown the yellow ca...  Yellow card         NaN  Home             AC Ajaccio               Toulouse        johan cavalli     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/france/ligue-1-2011-2012/ac-ajaccio-to...       True  2011-08-06      League One    2012   france           AC Ajaccio               Toulouse     0     2   2.80   3.10   3.05
# ...           ...          ...         ...   ...                                                ...          ...         ...   ...                    ...                    ...                  ...     ...       ...        ...        ...          ...      ...      ...      ...           ...       ...         ...                                                ...        ...         ...             ...     ...      ...                  ...                    ...   ...   ...    ...    ...    ...
# 940264  U7UC16b1/   U7UC16b199          99    63  Alessandro Gazzi (Palermo) is shown the yellow...  Yellow card         NaN  Home                Palermo         Internazionale     alessandro gazzi     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0      /soccer/italy/serie-a/palermo-inter-U7UC16b1/       True  2017-01-22         Serie A    2017    italy              Palermo         Internazionale     0     1   7.68   4.42   1.55
# 940280  U7UC16b1/  U7UC16b1115         115    78  Norbert Balogh (Palermo) is shown the yellow c...  Yellow card         NaN  Home                Palermo         Internazionale       norbert balogh     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0      /soccer/italy/serie-a/palermo-inter-U7UC16b1/       True  2017-01-22         Serie A    2017    italy              Palermo         Internazionale     0     1   7.68   4.42   1.55
# 940288  U7UC16b1/  U7UC16b1126         126    83  Alessandro Diamanti (Palermo) is shown the yel...  Yellow card         NaN  Home                Palermo         Internazionale  alessandro diamanti     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0      /soccer/italy/serie-a/palermo-inter-U7UC16b1/       True  2017-01-22         Serie A    2017    italy              Palermo         Internazionale     0     1   7.68   4.42   1.55
# 940298  U7UC16b1/  U7UC16b1136         136    91  Robin Quaison (Palermo) is shown the yellow ca...  Yellow card         NaN  Home                Palermo         Internazionale        robin quaison     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0      /soccer/italy/serie-a/palermo-inter-U7UC16b1/       True  2017-01-22         Serie A    2017    italy              Palermo         Internazionale     0     1   7.68   4.42   1.55
# 940382  UP9lzFAq/   UP9lzFAq88          88    85  Wes Morgan (Leicester City) is shown the yello...  Yellow card         NaN  Away         Leicester City            Southampton           wes morgan     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/england/premier-league/southampton-lei...       True  2017-01-22  Premier League    2017  england          Southampton         Leicester City     3     0   1.86   3.68   5.36
# 940410  vJy048Er/   vJy048Er22          22    26  Jakub Jankto (Udinese) is shown the yellow car...  Yellow card         NaN  Away                Udinese                 Empoli         jakub jankto     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0     /soccer/italy/serie-a/empoli-udinese-vJy048Er/       True  2017-01-22         Serie A    2017    italy               Empoli                Udinese     1     0   2.90   3.18   2.96
# 940415  vJy048Er/   vJy048Er29          29    32  Emil Hallfredsson (Udinese) is shown the yello...  Yellow card         NaN  Away                Udinese                 Empoli    emil hallfredsson     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0     /soccer/italy/serie-a/empoli-udinese-vJy048Er/       True  2017-01-22         Serie A    2017    italy               Empoli                Udinese     1     0   2.90   3.18   2.96
# 940427  vJy048Er/   vJy048Er41          41    40  Giuseppe Bellusci (Empoli) is shown the yellow...  Yellow card         NaN  Home                 Empoli                Udinese    giuseppe bellusci     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0     /soccer/italy/serie-a/empoli-udinese-vJy048Er/       True  2017-01-22         Serie A    2017    italy               Empoli                Udinese     1     0   2.90   3.18   2.96
# 940433  vJy048Er/   vJy048Er47          47    45  Manuel Pasqual (Empoli) is shown the yellow ca...  Yellow card         NaN  Home                 Empoli                Udinese       manuel pasqual     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0     /soccer/italy/serie-a/empoli-udinese-vJy048Er/       True  2017-01-22         Serie A    2017    italy               Empoli                Udinese     1     0   2.90   3.18   2.96
# 940440  vJy048Er/   vJy048Er57          57    48  Andrea Costa (Empoli) is shown the yellow card...  Yellow card         NaN  Home                 Empoli                Udinese         andrea costa     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0     /soccer/italy/serie-a/empoli-udinese-vJy048Er/       True  2017-01-22         Serie A    2017    italy               Empoli                Udinese     1     0   2.90   3.18   2.96
# 940459  vJy048Er/   vJy048Er76          76    63  Samir (Udinese) is shown the yellow card for a...  Yellow card         NaN  Away                Udinese                 Empoli                samir     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0     /soccer/italy/serie-a/empoli-udinese-vJy048Er/       True  2017-01-22         Serie A    2017    italy               Empoli                Udinese     1     0   2.90   3.18   2.96
# 940478  vJy048Er/   vJy048Er95          95    77  Andres Tello (Empoli) is shown the yellow card...  Yellow card         NaN  Home                 Empoli                Udinese         andres tello     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0     /soccer/italy/serie-a/empoli-udinese-vJy048Er/       True  2017-01-22         Serie A    2017    italy               Empoli                Udinese     1     0   2.90   3.18   2.96
# 940488  vJy048Er/  vJy048Er105         105    87  Sven Kums (Udinese) is shown the yellow card f...  Yellow card         NaN  Away                Udinese                 Empoli            sven kums     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0     /soccer/italy/serie-a/empoli-udinese-vJy048Er/       True  2017-01-22         Serie A    2017    italy               Empoli                Udinese     1     0   2.90   3.18   2.96
# 940528  xAkY8l6R/   xAkY8l6R32          32    34  Aleandro Rosi (Crotone) is shown the yellow ca...  Yellow card         NaN  Away                Crotone                  Genoa        aleandro rosi     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0      /soccer/italy/serie-a/genoa-crotone-xAkY8l6R/       True  2017-01-22         Serie A    2017    italy                Genoa                Crotone     2     2   1.97   4.35   8.00
# 940559  xAkY8l6R/   xAkY8l6R66          66    58  Danilo Cataldi (Genoa) is shown the yellow car...  Yellow card         NaN  Home                  Genoa                Crotone       danilo cataldi     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0      /soccer/italy/serie-a/genoa-crotone-xAkY8l6R/       True  2017-01-22         Serie A    2017    italy                Genoa                Crotone     2     2   1.97   4.35   8.00
# 940598  xAkY8l6R/  xAkY8l6R105         105    89  Lorenzo Crisetig (Crotone) is shown the yellow...  Yellow card         NaN  Away                Crotone                  Genoa     lorenzo crisetig     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0      /soccer/italy/serie-a/genoa-crotone-xAkY8l6R/       True  2017-01-22         Serie A    2017    italy                Genoa                Crotone     2     2   1.97   4.35   8.00
# 940608  xSU9scI9/   xSU9scI910          10     7  Michael Dawson (Hull City) is shown the yellow...  Yellow card         NaN  Away                   Hull                Chelsea       michael dawson     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/england/premier-league/chelsea-hull-ci...       True  2017-01-22  Premier League    2017  england              Chelsea                   Hull     2     0   1.19   8.50  20.00
# 940622  xSU9scI9/   xSU9scI927          27    26  Curtis Davies (Hull City) is shown the yellow ...  Yellow card         NaN  Away                   Hull                Chelsea        curtis davies     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/england/premier-league/chelsea-hull-ci...       True  2017-01-22  Premier League    2017  england              Chelsea                   Hull     2     0   1.19   8.50  20.00
# 940634  xSU9scI9/   xSU9scI939          39    43  N'Golo Kante (Chelsea) is shown the yellow car...  Yellow card         NaN  Home                Chelsea                   Hull          ngolo kante     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/england/premier-league/chelsea-hull-ci...       True  2017-01-22  Premier League    2017  england              Chelsea                   Hull     2     0   1.19   8.50  20.00
# 940653  xSU9scI9/   xSU9scI960          60    52  Andrew Robertson (Hull City) is shown the yell...  Yellow card         NaN  Away                   Hull                Chelsea     andrew robertson     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/england/premier-league/chelsea-hull-ci...       True  2017-01-22  Premier League    2017  england              Chelsea                   Hull     2     0   1.19   8.50  20.00
# 940695  xY7uZwOI/    xY7uZwOI8           8    11  Wesley Lautoa (Lorient) is shown the yellow ca...  Yellow card         NaN  Away                Lorient              AS Monaco        wesley lautoa     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0    /soccer/france/ligue-1/monaco-lorient-xY7uZwOI/       True  2017-01-22      League One    2017   france            AS Monaco                Lorient     4     0   1.32   6.24  11.50
# 940769  xY7uZwOI/   xY7uZwOI86          86    90  Djibril Sidibe (Monaco) is shown the yellow card.  Yellow card         NaN  Home              AS Monaco                Lorient       djibril sidibe     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0    /soccer/france/ligue-1/monaco-lorient-xY7uZwOI/       True  2017-01-22      League One    2017   france            AS Monaco                Lorient     4     0   1.32   6.24  11.50
# 940790  YyeGxMX8/   YyeGxMX825          25    21  Jean-Sylvain Babin (Sporting de Gijon) is show...  Yellow card         NaN  Away         Sporting Gijon             Real Betis    jeansylvain babin     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0         /soccer/spain/laliga/betis-gijon-YyeGxMX8/       True  2017-01-22         La Liga    2017    spain           Real Betis         Sporting Gijon     0     0   1.74   4.07   5.90
# 940841  YyeGxMX8/   YyeGxMX882          82    59  Dani Ceballos (Real Betis) is shown the yellow...  Yellow card         NaN  Home             Real Betis         Sporting Gijon        dani ceballos     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0         /soccer/spain/laliga/betis-gijon-YyeGxMX8/       True  2017-01-22         La Liga    2017    spain           Real Betis         Sporting Gijon     0     0   1.74   4.07   5.90
# 940871  YyeGxMX8/  YyeGxMX8112         112    84  Lillo (Sporting de Gijon) is shown the yellow ...  Yellow card         NaN  Away         Sporting Gijon             Real Betis                lillo     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0         /soccer/spain/laliga/betis-gijon-YyeGxMX8/       True  2017-01-22         La Liga    2017    spain           Real Betis         Sporting Gijon     0     0   1.74   4.07   5.90
# 940889  YyeGxMX8/  YyeGxMX8130         130    93  Bruno (Real Betis) is shown the yellow card fo...  Yellow card         NaN  Home             Real Betis         Sporting Gijon                bruno     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0         /soccer/spain/laliga/betis-gijon-YyeGxMX8/       True  2017-01-22         La Liga    2017    spain           Real Betis         Sporting Gijon     0     0   1.74   4.07   5.90
# 940917  z5L2OT5E/   z5L2OT5E30          30    28  Pedro Pereira (Sampdoria) is shown the yellow ...  Yellow card         NaN  Away              Sampdoria               Atalanta        pedro pereira     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/italy/serie-a/atalanta-sampdoria-z5L2O...       True  2017-01-22         Serie A    2017    italy             Atalanta              Sampdoria     1     0   1.79   3.96   5.40
# 940973  z5L2OT5E/   z5L2OT5E92          92    74  Jasmin Kurtic (Atalanta) is shown the yellow c...  Yellow card         NaN  Home               Atalanta              Sampdoria        jasmin kurtic     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/italy/serie-a/atalanta-sampdoria-z5L2O...       True  2017-01-22         Serie A    2017    italy             Atalanta              Sampdoria     1     0   1.79   3.96   5.40
# 940987  z5L2OT5E/  z5L2OT5E106         106    81  Filip Djuricic (Sampdoria) is shown the yellow...  Yellow card         NaN  Away              Sampdoria               Atalanta       filip djuricic     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/italy/serie-a/atalanta-sampdoria-z5L2O...       True  2017-01-22         Serie A    2017    italy             Atalanta              Sampdoria     1     0   1.79   3.96   5.40
# 940999  z5L2OT5E/  z5L2OT5E118         118    89  Milan Skriniar (Sampdoria) is shown the yellow...  Yellow card         NaN  Away              Sampdoria               Atalanta       milan skriniar     NaN       NaN        NaN        UNK          UNK    False      UNK      UNK           UNK       NaN           0  /soccer/italy/serie-a/atalanta-sampdoria-z5L2O...       True  2017-01-22         Serie A    2017    italy             Atalanta              Sampdoria     1     0   1.79   3.96   5.40
#
#         odd_over  odd_under  odd_bts  odd_bts_n
# 44           NaN        NaN      NaN        NaN
# 76           NaN        NaN      NaN        NaN
# 79           NaN        NaN      NaN        NaN
# 101          NaN        NaN      NaN        NaN
# 118          NaN        NaN      NaN        NaN
# 125          NaN        NaN      NaN        NaN
# 153          NaN        NaN      NaN        NaN
# 192          NaN        NaN      NaN        NaN
# 218          NaN        NaN      NaN        NaN
# 231          NaN        NaN      NaN        NaN
# 258          NaN        NaN      NaN        NaN
# 330          NaN        NaN      NaN        NaN
# 336          NaN        NaN      NaN        NaN
# 394          NaN        NaN      NaN        NaN
# 408          NaN        NaN      NaN        NaN
# 474          NaN        NaN      NaN        NaN
# 477          NaN        NaN      NaN        NaN
# 496          NaN        NaN      NaN        NaN
# 552          NaN        NaN      NaN        NaN
# 572          NaN        NaN      NaN        NaN
# 599          NaN        NaN      NaN        NaN
# 639          NaN        NaN      NaN        NaN
# 658          NaN        NaN      NaN        NaN
# 677          NaN        NaN      NaN        NaN
# 701          NaN        NaN      NaN        NaN
# 743          NaN        NaN      NaN        NaN
# 752          NaN        NaN      NaN        NaN
# 760          NaN        NaN      NaN        NaN
# 813          NaN        NaN      NaN        NaN
# 864          NaN        NaN      NaN        NaN
# ...          ...        ...      ...        ...
# 940264      1.80       2.22     1.91       2.04
# 940280      1.80       2.22     1.91       2.04
# 940288      1.80       2.22     1.91       2.04
# 940298      1.80       2.22     1.91       2.04
# 940382      2.40       1.74     2.17       1.75
# 940410      2.55       1.64     2.05       1.85
# 940415      2.55       1.64     2.05       1.85
# 940427      2.55       1.64     2.05       1.85
# 940433      2.55       1.64     2.05       1.85
# 940440      2.55       1.64     2.05       1.85
# 940459      2.55       1.64     2.05       1.85
# 940478      2.55       1.64     2.05       1.85
# 940488      2.55       1.64     2.05       1.85
# 940528      1.95       2.03     2.03       1.86
# 940559      1.95       2.03     2.03       1.86
# 940598      1.95       2.03     2.03       1.86
# 940608      1.54       2.68     2.40       1.66
# 940622      1.54       2.68     2.40       1.66
# 940634      1.54       2.68     2.40       1.66
# 940653      1.54       2.68     2.40       1.66
# 940695      1.53       3.08     1.80       2.25
# 940769      1.53       3.08     1.80       2.25
# 940790      2.20       1.89     2.05       1.86
# 940841      2.20       1.89     2.05       1.86
# 940871      2.20       1.89     2.05       1.86
# 940889      2.20       1.89     2.05       1.86
# 940917      1.90       2.07     1.80       2.16
# 940973      1.90       2.07     1.80       2.16
# 940987      1.90       2.07     1.80       2.16
# 940999      1.90       2.07     1.80       2.16
#
# [39911 rows x 39 columns]

# %% [markdown]
# ### Graph to show when the second yellow cards are most likely to be served

# %%
# plot the red cards against time of playing the game

fig3 = plt.figure(figsize=(14,8))
plt.hist(second_yellow_cards.time, 100, color="yellow")
plt.xlabel("Minute of the Game")
plt.ylabel("Second Yellow Cards")
plt.title("When Second Yellow Cards Occur")
# Out:
# Text(0.5, 1.0, 'When Second Yellow Cards Occur')

# %% [markdown]
# ### Generally when are cards likely to be served

# %%
# Get the yellow cards against time of playing the game
fig4 = plt.figure(figsize=(14,8))                                                            
plt.hist(all_cards.time, 100, color="orange")
plt.xlabel("Minute  of the Game")
plt.ylabel("Cards served")
plt.title("When cards are served")
# Out:
# Text(0.5, 1.0, 'When cards are served')

# %% [markdown]
# ### Distribution of serving of yellow cards as per the leagues

# %%
yellow_league = pd.crosstab(index=yellow_cards.event_type, columns=yellow_cards.league)
yellow_league.plot(kind='bar', figsize=(14,14))

# %% [markdown]
# ### Distibution of red cards as per the league

# %%
red_league = pd.crosstab(index=red_cards.event_type, columns=red_cards.league)
red_league .plot(kind='bar', figsize=(14,14))

# %% [markdown]
# ### Get cards served per league

# %%
player_red_card = (red_cards[['player', 'league']])
league_one = player_red_card [player_red_card.league == 'League One'].groupby('player').count()
La_Liga = player_red_card [player_red_card.league == 'La Liga'].groupby('player').count()
Bundesliga = player_red_card [player_red_card.league == 'Bundesliga'].groupby('player').count()
Serie_A = player_red_card [player_red_card.league == 'Serie A'].groupby('player').count()
Premier_League = player_red_card [player_red_card.league == 'Premier League'].groupby('player').count()


player_red_card_yellow = (yellow_cards[['player', 'league']])
league_one_yellow = player_red_card_yellow [player_red_card_yellow.league == 'League One'].groupby('player').count()
La_Liga_yellow = player_red_card_yellow [player_red_card_yellow.league == 'La Liga'].groupby('player').count()
Bundesliga_yellow = player_red_card_yellow[player_red_card_yellow.league == 'Bundesliga'].groupby('player').count()
Serie_A_yellow = player_red_card_yellow[player_red_card_yellow.league == 'Serie A'].groupby('player').count()
Premier_League_yellow = player_red_card_yellow[player_red_card_yellow.league == 'Premier League'].groupby('player').count()

league_one.columns=['league_one_red']
La_Liga.columns=['La_Liga_red']
Bundesliga.columns=['Bundesliga_red']
Serie_A.columns=['Serie_A_red']
Premier_League.columns=['Premier_League_red']

league_one_yellow.columns=['league_one_yellow']
La_Liga_yellow.columns=['La_Liga_yellow_']
Bundesliga_yellow.columns=['Bundesliga_yellow']
Serie_A_yellow.columns=['Serie_A_yellow']
Premier_League_yellow.columns=['Premier_League_yellow']

cards_per_league = pd.concat([league_one, La_Liga, Bundesliga, Serie_A,  Premier_League,league_one_yellow, \
                              La_Liga_yellow, Bundesliga_yellow, Serie_A_yellow,  Premier_League_yellow]).fillna(0)

# %% [markdown]
# ### When are goals most likely to be scored

# %%
goals=df_unique_events[df_unique_events["is_goal"]==1]

fig4=plt.figure(figsize=(14,8))
plt.hist(goals.time,width=1,bins=100,color="green")   #100 so 1 bar per minute
plt.xlabel("Minutes")
plt.ylabel("Number of goals")
plt.title("Number of goals against Time during match")
# Out:
# Text(0.5, 1.0, 'Number of goals against Time during match')
